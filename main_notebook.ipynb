# %% [markdown]
# # Use this notebook for your 3 choices of APIs

# %% [markdown]
# ## Finance
# ## Bank Data API
# ### Get banks SWIFT and IBAN codes (500) of Germany
#
#
# https://apilayer.com/marketplace/bank_data-api?txn=free&live_demo=show

# %%
import pandas as pd
import requests

# %%
url = "https://api.apilayer.com/bank_data/all?per_page=500&country=DE"

payload = {}
headers= {
  "apikey": "wfZ6uSCEtk5XXSmQEa4vnHUeYy5AYMRN"
}

response = requests.request("GET", url, headers=headers, data = payload)

status_code = response.status_code
result = response.json()
# result

# %%
flattened_data = pd.json_normalize(result['data'])
flattened_data = flattened_data.drop(['iban_data.ISO_country_code','swift_data.address'] ,axis = 1)
flattened_data
# Out:
#              iban_data.iban iban_data.checksum iban_data.bank_code  \
# 0    DE89370400440532013000                 89            37040044
# 1    DE89370400440532013000                 89            37040044
# 2    DE89370400440532013000                 89            37040044
# 3    DE89370400440532013000                 89            37040044
# 4    DE89370400440532013000                 89            37040044
# ..                      ...                ...                 ...
# 495  DE89370400440532013000                 89            37040044
# 496  DE89370400440532013000                 89            37040044
# 497  DE89370400440532013000                 89            37040044
# 498  DE89370400440532013000                 89            37040044
# 499  DE89370400440532013000                 89            37040044
#
#     iban_data.account_number swift_data.swift  \
# 0                 0532013000         TRSYDEFF
# 1                 0532013000         AGGBDE51
# ...

# %% [markdown]
# ## Cryptocurrency
# ## CoinCap
# https://docs.coincap.io/

# %%
url = 'https://api.coincap.io/v2/assets'        
response = requests.get(url)
status_code = response.status_code
result = response.json()
# result 
flattened_data = pd.json_normalize(result['data'])
flattened_data
# Out:
#                        id rank symbol                   name  \
# 0                 bitcoin    1    BTC                Bitcoin
# 1                ethereum    2    ETH               Ethereum
# 2                  tether    3   USDT                 Tether
# 3            binance-coin    4    BNB                    BNB
# 4                     xrp    5    XRP                    XRP
# ..                    ...  ...    ...                    ...
# 95                   aelf   96    ELF                   aelf
# 96                   qtum   97   QTUM                   Qtum
# 97                    nem   98    XEM                    NEM
# 98  basic-attention-token   99    BAT  Basic Attention Token
# 99                 helium  100    HNT                 Helium
#
#                           supply                      maxSupply  \
# 0      19547062.0000000000000000      21000000.0000000000000000
# 1     120252683.5477615300000000                           None
# ...

# %% [markdown]
# ## Health
# ## openFDA
#
# https://open.fda.gov/apis/drug/event/how-to-use-the-endpoint/

# %%
url = 'https://api.fda.gov/drug/event.json?api_key=5nRzREopkz50ZHSNInpJLfdL72gyzWb3qmdRUGFQ&search=receivedate:[20040101+TO+20081231]&limit=300'        
response = requests.get(url)
status_code = response.status_code
result = response.json()
# result
flattened_data = pd.json_normalize(result['results'])
flattened_data = flattened_data.drop(['receiver','patient.patientdeath.patientdeathdateformat','patient.patientdeath.patientdeathdate','primarysource','patient.reaction','patient.drug'] ,axis = 1)
flattened_data
# Out:
#     safetyreportid transmissiondateformat transmissiondate serious  \
# 0        5801206-7                    102         20090109       1
# 1        4318221-5                    102         20041129       1
# 2        5015436-8                    102         20061013       1
# 3        4412763-X                    102         20050211       1
# 4        4338356-0                    102         20050107       1
# ..             ...                    ...              ...     ...
# 295      4809372-7                    102         20060501       2
# 296      4638049-6                    102         20051028       1
# 297      4378197-1                    102         20050107       1
# 298      4556603-7                    102         20050727       1
# 299      5099201-1                    102         20061208       1
#
#     seriousnessdeath receivedateformat receivedate receiptdateformat  \
# 0                  1               102    20080707               102
# ...
